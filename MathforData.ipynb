# %% [markdown]
# <a href="https://colab.research.google.com/github/bgreenberg30/MathforData/blob/main/MathforData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Notes
#
# <img src="https://muralsyourway.vtexassets.com/arquivos/ids/233131-825-auto?width=825&height=auto&aspect=true">

# %% [markdown]
# <img src="https://businessoverbroadway.com/wp-content/uploads/2018/04/median_salary_world_DS_MLE.png">

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.random.random()

# %%
A
# Out:
# array([[0.61014593, 0.8123584 , 0.30910202, 0.194772  , 0.79662077]])

# %%
A = np.random.random((1,5))

# %%
B = np.random.random((1,5))

# %%
A,B
# Out:
# (array([[0.61014593, 0.8123584 , 0.30910202, 0.194772  , 0.79662077]]),
#  array([[0.03314412, 0.85347049, 0.10726892, 0.27508146, 0.52177247]]))

# %%
A = A.T
B = B.T

# %%
plt.plot(A,B)

# %%
plt.plot(A,B)

# %%
plt.plot(A,B, 'r.')

# %%
X = np.random.random((100,1))
Y = np.random.random((100,1))
plt.plot(X,Y, 'g--')

# %%
print(A.shape,B.shape,X.shape,Y.shape)
# Out:
# (5, 1) (5, 1) (100, 1) (100, 1)

# %%
Z = np.random.random((100,100))
print(Z.shape)
print(Z)
# Out:
# (100, 100)
# [[0.71698725 0.5636445  0.37642396 ... 0.94194783 0.26844883 0.2252977 ]
#  [0.24350944 0.9044411  0.82021347 ... 0.47451256 0.41047053 0.66041302]
#  [0.10181443 0.59615059 0.38598868 ... 0.02698596 0.94591743 0.31854322]
#  ...
#  [0.17957974 0.89291023 0.33904755 ... 0.01289758 0.63667036 0.54467297]
#  [0.85419424 0.17631282 0.37055789 ... 0.3913192  0.75925229 0.44371578]
#  [0.2687035  0.01197682 0.35876481 ... 0.26553596 0.25973748 0.8957023 ]]

# %%
plt.imshow(Z)
